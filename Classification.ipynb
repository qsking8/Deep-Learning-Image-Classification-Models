# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir /content/train_local
# %cp -av /content/drive/MyDrive/Deep-Learning-Image-Classification-Models/Datasets/flower.zip /content/train_local
# !pip install pyunpack
# !pip install patool
from pyunpack import Archive
Archive('/content/train_local/flower.zip').extractall('/content/train_local')
# Out:
# '/content/drive/MyDrive/Deep-Learning-Image-Classification-Models/Datasets/flower.zip' -> '/content/train_local/flower.zip'
# ...

# %%
import os
path="/content/drive/MyDrive/Deep-Learning-Image-Classification-Models"
os.chdir(path)
# !python train_sample.py //注意colab中执行命令前要加！
# Out:
# using cuda:0 device.
# using 3306 images for training, 364 images for validation.
# train epoch[1/100] loss:1.277: 100%|████████████████████████████████| 52/52 [00:55<00:00,  1.06s/it]
# [epoch 1] train_loss: 1.277  train_acc: 0.346  val_accuracy: 0.445
# train epoch[2/100] loss:1.502: 100%|████████████████████████████████| 52/52 [00:54<00:00,  1.04s/it]
# [epoch 2] train_loss: 1.502  train_acc: 0.461  val_accuracy: 0.464
# train epoch[3/100] loss:0.888: 100%|████████████████████████████████| 52/52 [00:54<00:00,  1.05s/it]
# [epoch 3] train_loss: 0.888  train_acc: 0.541  val_accuracy: 0.549
# train epoch[4/100] loss:0.877: 100%|████████████████████████████████| 52/52 [00:54<00:00,  1.05s/it]
# [epoch 4] train_loss: 0.877  train_acc: 0.588  val_accuracy: 0.585
# train epoch[5/100] loss:1.000: 100%|████████████████████████████████| 52/52 [00:54<00:00,  1.05s/it]
# [epoch 5] train_loss: 1.000  train_acc: 0.615  val_accuracy: 0.624
# ...
